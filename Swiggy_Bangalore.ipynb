# %%
import pandas as pd 
import numpy as np 
from google.colab import files 
uploaded = files.upload() 
df = pd.read_csv('Swiggy Bangalore.csv')
# Out:
#      <input type="file" id="files-6fbc428a-322c-45c0-a44f-d828f29f4aa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fbc428a-322c-45c0-a44f-d828f29f4aa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Swiggy Bangalore.csv to Swiggy Bangalore (1).csv

# %%
df
# Out:
#                            Restaurant Name  \
# 0                         Khichdi Paradise
# 1                     Home Plate by EatFit
# 2                          THE GRILL & CO.
# 3      555 Darjeeling Unique Asian Cuisine
# 4                                Momo Guy
# ...                                    ...
# 10292                            Holy Chic
# 10293                           PAPA ROLLS
# 10294                          RICE SAMBAR
# 10295              Paris Family Restaurant
# 10296                        Swarna's Atil
#
#                                                 Category  Rating  \
# 0           Home Food, Desserts, Beverages, Healthy Food     NaN
# 1      North Indian, Home Food, Healthy Food, Indian,...     3.9
# 2                               Indian, Tandoor, Biryani     NaN
# 3                                                  Asian     NaN
# 4                    Asian, Tibetan, Desserts, Beverages     NaN
# ...

# %%
df['Rating'] = df['Rating'].fillna('')

# %%
df['Offer']=df['Offer'].fillna('')

# %%
df['Cost for one'] = df['Cost for Two (in Rupees)']/2

# %%
df
# Out:
#                            Restaurant Name  \
# 0                         Khichdi Paradise
# 1                     Home Plate by EatFit
# 2                          THE GRILL & CO.
# 3      555 Darjeeling Unique Asian Cuisine
# 4                                Momo Guy
# ...                                    ...
# 10292                            Holy Chic
# 10293                           PAPA ROLLS
# 10294                          RICE SAMBAR
# 10295              Paris Family Restaurant
# 10296                        Swarna's Atil
#
#                                                 Category Rating  \
# 0           Home Food, Desserts, Beverages, Healthy Food
# 1      North Indian, Home Food, Healthy Food, Indian,...    3.9
# 2                               Indian, Tandoor, Biryani
# 3                                                  Asian
# 4                    Asian, Tibetan, Desserts, Beverages
# ...                                                  ...    ...
# ...

# %%
df1= df.groupby(['Area'])['Cost for one'].max().reset_index(name='Maximum Amount').sort_values('Maximum Amount', ascending = False)

# %% [markdown]
# **Top 5 areas with serving expensive food**

# %%
dff1=df1.head(5) 
dff1
# Out:
#                  Area  Maximum Amount
# 6   Central Bangalore          1750.0
# 21           Majestic          1250.0
# 28         Whitefield          1200.0
# 29          Yelahanka          1011.0
# 13          Jayanagar          1000.0

# %% [markdown]
# **Top 5 restaurants serving food for reasonable **
#
#
# 1.   List item
# 2.   List item

# %%
dff2 = df1.tail(5).sort_values('Maximum Amount', ascending = True)
dff2
# Out:
#                  Area  Maximum Amount
# 25        Rajajinagar           150.0
# 17    Kanakapura Road           400.0
# 3   Basaveshwaranagar           400.0
# 15           Kadugodi           450.0
# 23    Nagavara Hennur           500.0

# %%
df2=pd.merge(df,dff1,left_on  =  ['Area', 'Cost for one'],  right_on = ['Area','Maximum Amount'],how='inner')  
#df2= pd.merge(df,dff1, on = 'Area', how = 'inner')

# %%
df2[['Restaurant Name','Area', 'Cost for one']]
# Out:
#          Restaurant Name               Area  Cost for one
# 0            Olive Beach  Central Bangalore        1750.0
# 1              Theobroma          Jayanagar        1000.0
# 2  Glass Kitchen And Bar           Majestic        1250.0
# 3              The Layla         Whitefield        1200.0
# 4         Zafran biryani          Yelahanka        1011.0

# %%
e = list(df2['Restaurant Name']) 
e
# Out:
# ['Olive Beach',
#  'Theobroma',
#  'Glass Kitchen And Bar',
#  'The Layla',
#  'Zafran biryani']

# %%
df7=df[~df['Restaurant Name'].isin(e)]

# %%
df8=df7.groupby(['Area'])['Cost for one'].max().reset_index(name='Maximum Amount1').sort_values('Maximum Amount1',ascending = False).head(5)

# %% [markdown]
# **Top 5 Areas serving expensive food after excluding the Ezpensive Restaurants of that area. **
#
# *   List item
# *   List item

# %%
display(df8) 
display(dff1)
# Out:
#                  Area  Maximum Amount1
# 6   Central Bangalore           1000.0
# 28         Whitefield           1000.0
# 10                HSR            900.0
# 11        Indiranagar            900.0
# 14   Kadubeesanahalli            750.0
#                  Area  Maximum Amount
# 6   Central Bangalore          1750.0
# 21           Majestic          1250.0
# 28         Whitefield          1200.0
# 29          Yelahanka          1011.0
# 13          Jayanagar          1000.0

# %%
df['Rating']=df['Rating'].replace('',-1)

# %%
df['Rating'].unique()
# Out:
# array([-1. ,  3.9,  3.7,  3.8,  3.4,  3.3,  3.6,  3.5,  3.2,  3.1,  3. ])

# %%
df2=df.groupby('Rating').max().sort_values('Rating',ascending=False).head(5)
df2
# Out:
#                    Restaurant Name  \
# Rating
# 3.9     chole bhatura and parathas
# 3.8                slv food corner
# 3.7                  litti Bhandar
# 3.6                 veg cake house
# 3.5                 mahifoodcorner
#
#                                                  Category  \
# Rating
# 3.9                           Tibetan, Bhutanese, Chinese
# 3.8     Waffle, Desserts, Ice Cream, European, America...
# 3.7       Tibetan, Chinese, Asian, Street Food, Fast Food
# 3.6     Tandoor, Mughlai, Arabian, North Indian, Chine...
# 3.5       Tibetan, Chinese, Asian, Street Food, Fast Food
#
#         Cost for Two (in Rupees)          Area Offer  \
# Rating
# 3.9                         1600  Yeshwanthpur
# 3.8                         1200  Yeshwanthpur
# 3.7                         1200  Yeshwanthpur
# 3.6                         1200  Yeshwanthpur
# 3.5                         1000  Yeshwanthpur
#
#                                                       URL  Cost for one
# ...

# %%
df2[[ 'Restaurant Name', 'Area','Cost for one']]
# Out:
#                    Restaurant Name          Area  Cost for one
# Rating
# 3.9     chole bhatura and parathas  Yeshwanthpur         800.0
# 3.8                slv food corner  Yeshwanthpur         600.0
# 3.7                  litti Bhandar  Yeshwanthpur         600.0
# 3.6                 veg cake house  Yeshwanthpur         600.0
# 3.5                 mahifoodcorner  Yeshwanthpur         500.0

# %%
df3=df[df['Rating']==max(df['Rating'])]

# %% [markdown]
# **The Average Cost per person of all restaurants with maximum rating is: **

# %%
Average_cost = np.mean(df3['Cost for one'])

# %%
df4=df[df['Rating']==min(df['Rating'])]

# %% [markdown]
# ** The Average Cost per person of all restaurants with minimum rating is **

# %%
Average_Cost = np.mean(df4['Cost for one'])
